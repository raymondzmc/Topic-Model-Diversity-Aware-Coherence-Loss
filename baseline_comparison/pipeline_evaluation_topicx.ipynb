# %%
import sys
sys.path.append('topicx/')

from baselines.cetopictm import CETopicTM
from utils import prepare_dataset
import baseline_utils
from sklearn.feature_extraction.text import CountVectorizer
from octis.dataset.dataset import Dataset
import random 
import pickle

# %%
dataset_name = '20news'
number_topic_models = 2
list_number_of_topics = [25,50]
sbert_model_name = 'all-mpnet-base-v2'
word2vec_path = '/mnt/datasets/VIST/data/commonsense_ctm_data/GoogleNews-vectors-negative300.bin.gz'

# %%
dataset = Dataset()

if dataset_name == '20news':
    dataset.load_custom_dataset_from_folder("resources_octis/20news")
if dataset_name == 'dbpedia':
    dataset.load_custom_dataset_from_folder("resources_octis/dbpedia")
if dataset_name =='google_news':
    dataset.load_custom_dataset_from_folder("resources_octis/google_news")

# %%
texts = dataset.get_corpus()
texts = [' '.join(text) for text in texts]

# %%
key_name = 'results/topicx_'+dataset_name+'_NTM_'+str(number_topic_models)+'_ntopics_'+str(list_number_of_topics)+'_embedding_'+sbert_model_name+'.pkl'
print('key_name', key_name)
# Out:
# key_name results/topicx_20news_NTM_2_ntopics_[25, 50]_embedding_all-mpnet-base-v2.pkl

# %%
from datetime import datetime
start_time = datetime.now()

final_results = []
for current_number_of_topics in list_number_of_topics:
    for i in range(number_topic_models):
        random_seed_number = random.randint(0, 1000)
        print('Random seed number: {}'.format(random_seed_number))


        tm = CETopicTM(dataset=dataset, 
                    topic_model='cetopic', 
                    num_topics=current_number_of_topics, 
                    dim_size=50,#In the paper the authors say 'we reduce the dimensionality of sentence embedding to 50 usign UMAP' #default 5 
                    word_select_method='tfidf_idfi', #best word selection method according to their paper
                    embedding='/mnt/datasets/SBERT/'+sbert_model_name,
                    seed=random_seed_number)  #sentence-transformers/all-mpnet-base-v2', #embedding='princeton-nlp/unsup-simcse-bert-base-uncased',  #Default in Raymond's evaluation is: all-mpnet-base-v2 #TODO: I think we must use a different embedding)
        
        tm.train()

        #td_score, cv_score, npmi_score = tm.evaluate()
        #print(f'td: {td_score} npmi: {npmi_score} cv: {cv_score}')

        topics = tm.get_topics()
        print(f'Topics: {topics}')

        formatted_topics_list = []

        for key, value in topics.items():
            #new_list.append(topic.split())
            list_current_topic = []
            for keyword, score in value:
                list_current_topic.append(keyword)
            #print(list_current_topic)
            formatted_topics_list.append(list_current_topic)

        npmi_score, we_score, irbo_score, td_score = baseline_utils.evaluate(formatted_topics_list, texts, embeddings_path=word2vec_path)
        dict_results = {'npmi_score': npmi_score, 'we_score': we_score, 'irbo_score': irbo_score, 'td_score': td_score}
        print(dict_results)
        final_results.append(dict_results)

        output = open(key_name, 'wb')
        pickle.dump(final_results, output)
        output.close()
        end_time  =datetime.now()
        print('Duration: {}'.format(end_time - start_time))

output = open(key_name, 'wb')
pickle.dump(final_results, output)
output.close()
# Out:
# Random seed number: 279
# Initialize CETopicTM with num_topics=25, embedding=/mnt/datasets/SBERT/all-mpnet-base-v2
# ====== Using TFIDF_IDFi ======
# Topics: {0: [('morality', 0.007924123353806092), ('article', 0.007509111950931161), ('people', 0.0072568644277435776), ('objective', 0.006795872524744639), ('think', 0.0064857723446847615), ('dont', 0.005579055479196847), ('just', 0.00529419214581915), ('evidence', 0.004833451631825757), ('say', 0.00440508098814201), ('moral', 0.004306914360134347)], 1: [('radio', 0.007896098725012873), ('tape', 0.007873014203870756), ('battery', 0.0069355483369465416), ('audio', 0.006115110444749674), ('use', 0.005595446324983719), ('cd', 0.005483803179234133), ('sound', 0.005455724644273408), ('circuit', 0.005251386679415793), ('used', 0.00514182991266607), ('like', 0.004965471854358432)], 2: [('israel', 0.026925451825609337), ('jews', 0.02405723074740101), ('israeli', 0.02248659210858313), ('jewish', 0.02048334260402525), ('arab', 0.016779225955958797), ('arabs', 0.01579789717218034), ('muslims', 0.012586759806051008), ('islam', 0.010166355994850272), ('palestinian', 0.009467942668963314), ('islamic', 0.007513669438724245)], 3: [('game', 0.011449690421236213), ('baseball', 0.00912348714329132), ('season', 0.008462244023573075), ('team', 0.008044028724804808), ('hit', 0.008020050098926007), ('year', 0.007962744255056439), ('hes', 0.007675829920696679), ('players', 0.007048366204630762), ('david', 0.006988637853126987), ('think', 0.006844472271908788)], 4: [('koresh', 0.008763649347261596), ('fbi', 0.00840287092323176), ('batf', 0.00798287658591246), ('gun', 0.007280792444590957), ('people', 0.006853306512150159), ('government', 0.005903650498816066), ('guns', 0.005789962331143409), ('dont', 0.005436529054752956), ('weapons', 0.004896171437705891), ('waco', 0.00483903277810338)], 5: [('motif', 0.020246877337510523), ('window', 0.01720714110906119), ('xterm', 0.013103902996463032), ('x11r5', 0.013094578194705497), ('widget', 0.01228425065283457), ('font', 0.011524055978216246), ('fonts', 0.010416169119433943), ('server', 0.009089980521872642), ('program', 0.008182177317485377), ('openwindows', 0.008147374238138374)], 6: [('end', 0.8552966036965862), ('begin', 0.05084035928777897), ('factor', 0.04391797180741724), ('got', 0.025071532505425733), ('going', 0.02487353270279196), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)], 7: [('card', 0.025451041384593774), ('monitor', 0.023091521514536896), ('vga', 0.014803900657904889), ('video', 0.01337975834516617), ('color', 0.011993604191565081), ('drivers', 0.011219892659727738), ('cards', 0.00978616934218751), ('monitors', 0.009046097199240167), ('colors', 0.009019979336484763), ('driver', 0.008660339120357624)], 8: [('car', 0.023201938339137456), ('cars', 0.012813887587734593), ('ford', 0.009494101675672358), ('engine', 0.009439215606188772), ('oil', 0.0073917680915633515), ('miles', 0.006581167271065383), ('radar', 0.006507266918468669), ('dealer', 0.006419158911735603), ('turbo', 0.00621464855198018), ('just', 0.0058858870261889575)], 9: [('encryption', 0.023722586681727), ('clipper', 0.020861264160371644), ('nsa', 0.016137556308290033), ('key', 0.014546622507018237), ('escrow', 0.013195168917095223), ('chip', 0.012036107658177673), ('crypto', 0.010674524739024471), ('keys', 0.009956551176483313), ('encrypted', 0.008021883002191702), ('government', 0.008010902915673444)], 10: [('god', 0.015307884883596655), ('jesus', 0.01328026250778212), ('bible', 0.009036788832101425), ('christian', 0.008965643170961747), ('church', 0.008929938638815539), ('christians', 0.008426573487160915), ('christ', 0.007793745315005167), ('homosexual', 0.007342865277377456), ('people', 0.006407681513653872), ('homosexuality', 0.006259318177212117)], 11: [('msg', 0.009770973093956034), ('disease', 0.00948399410637741), ('medical', 0.008581760941095662), ('drug', 0.008546126986538635), ('patients', 0.008503606833992533), ('cancer', 0.008202889959072483), ('doctor', 0.0077642591311881575), ('drugs', 0.007011830504495541), ('health', 0.006730796081417421), ('infection', 0.006592534165064103)], 12: [('3d', 0.0125 ...
# 03/13/2023 21:12:33 - INFO - gensim.corpora.dictionary -   adding document #0 to Dictionary<0 unique tokens: []>
# 03/13/2023 21:12:33 - INFO - gensim.corpora.dictionary -   adding document #10000 to Dictionary<2000 unique tokens: ['actually', 'beat', 'better', 'bit', 'couple']...>
# 03/13/2023 21:12:33 - INFO - gensim.corpora.dictionary -   built Dictionary<2000 unique tokens: ['actually', 'beat', 'better', 'bit', 'couple']...> from 18173 documents (total 909509 corpus positions)
# 03/13/2023 21:12:33 - INFO - gensim.utils -   Dictionary lifecycle event {'msg': "built Dictionary<2000 unique tokens: ['actually', 'beat', 'better', 'bit', 'couple']...> from 18173 documents (total 909509 corpus positions)", 'datetime': '2023-03-13T21:12:33.571359', 'gensim': '4.2.0', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-84-generic-x86_64-with-glibc2.29', 'event': 'created'}
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.probability_estimation -   using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   1 batches submitted to accumulate stats from 64 documents (1988 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   2 batches submitted to accumulate stats from 128 documents (3976 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   3 batches submitted to accumulate stats from 192 documents (5621 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   4 batches submitted to accumulate stats from 256 documents (7721 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   5 batches submitted to accumulate stats from 320 documents (9678 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   6 batches submitted to accumulate stats from 384 documents (11167 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   7 batches submitted to accumulate stats from 448 documents (14293 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   8 batches submitted to accumulate stats from 512 documents (15866 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   9 batches submitted to accumulate stats from 576 documents (18128 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   10 batches submitted to accumulate stats from 640 documents (22696 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   11 batches submitted to accumulate stats from 704 documents (26110 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   12 batches submitted to accumulate stats from 768 documents (28759 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   13 batches submitted to accumulate stats from 832 documents (30915 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   14 batches submitted to accumulate stats from 896 documents (32734 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   15 batches submitted to accumulate stats from 960 documents (34559 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   16 batches submitted to accumulate stats from 1024 documents (36360 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   17 batches submitted to accumulate stats from 1088 documents (38285 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   18 batches submitted to accumulate stats from 1152 documents (40402 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   19 batches submitted to accumulate stats from 1216 documents (43155 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   20 batches submitted to accumulate stats from 1280 documents (45400 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   21 batches submitted to accumulate stats from 1344 documents (50135 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   22 batches submitted to accumulate stats from 1408 documents (52423 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   23 batches submitted to accumulate stats from 1472 documents (54629 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   24 batches submitted to accumulate stats from 1536 documents (56451 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   25 batches submitted to accumulate stats from 1600 documents (58923 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   26 batches submitted to accumulate stats from 1664 documents (60586 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   27 batches submitted to accumulate stats from 1728 documents (62434 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   28 batches submitted to accumulate stats from 1792 documents (64563 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   29 batches submitted to accumulate stats from 1856 documents (68237 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   30 batches submitted to accumulate stats from 1920 documents (73065 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   31 batches submitted to accumulate stats from 1984 documents (75660 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   32 batches submitted to accumulate stats from 2048 documents (79057 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   33 batches submitted to accumulate stats from 2112 documents (80104 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   34 batches submitted to accumulate stats from 2176 documents (83459 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   35 batches submitted to accumulate stats from 2240 documents (87265 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   36 batches submitted to accumulate stats from 2304 documents (90132 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   37 batches submitted to accumulate stats from 2368 documents (92537 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   38 batches submitted to accumulate stats from 2432 documents (94859 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   39 batches submitted to accumulate stats from 2496 documents (99448 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   40 batches submitted to accumulate stats from 2560 documents (101590 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   41 batches submitted to accumulate stats from 2624 documents (104396 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   42 batches submitted to accumulate stats from 2688 documents (106656 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   43 batches submitted to accumulate stats from 2752 documents (113565 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   44 batches submitted to accumulate stats from 2816 documents (115257 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   45 batches submitted to accumulate stats from 2880 documents (118265 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   46 batches submitted to accumulate stats from 2944 documents (119869 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   47 batches submitted to accumulate stats from 3008 documents (121289 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   48 batches submitted to accumulate stats from 3072 documents (122867 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   49 batches submitted to accumulate stats from 3136 documents (124703 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   50 batches submitted to accumulate stats from 3200 documents (126620 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   51 batches submitted to accumulate stats from 3264 documents (130239 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   52 batches submitted to accumulate stats from 3328 documents (131901 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   53 batches submitted to accumulate stats from 3392 documents (137159 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   54 batches submitted to accumulate stats from 3456 documents (139923 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   55 batches submitted to accumulate stats from 3520 documents (144933 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   56 batches submitted to accumulate stats from 3584 documents (146182 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   57 batches submitted to accumulate stats from 3648 documents (148067 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   58 batches submitted to accumulate stats from 3712 documents (149804 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   59 batches submitted to accumulate stats from 3776 documents (152545 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   60 batches submitted to accumulate stats from 3840 documents (155051 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   61 batches submitted to accumulate stats from 3904 documents (159880 virtual)
# 03/13/2023 21:12:33 - INFO - gensim.topic_coherence.text_analysis -   62 batches submitted to accumulate stats from 3968 documents (161491 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   63 batches submitted to accumulate stats from 4032 documents (165020 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   64 batches submitted to accumulate stats from 4096 documents (169596 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   65 batches submitted to accumulate stats from 4160 documents (172218 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   66 batches submitted to accumulate stats from 4224 documents (176369 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   67 batches submitted to accumulate stats from 4288 documents (178724 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   68 batches submitted to accumulate stats from 4352 documents (180520 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   69 batches submitted to accumulate stats from 4416 documents (181830 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   70 batches submitted to accumulate stats from 4480 documents (184211 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   71 batches submitted to accumulate stats from 4544 documents (188161 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   72 batches submitted to accumulate stats from 4608 documents (191703 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   73 batches submitted to accumulate stats from 4672 documents (196523 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   74 batches submitted to accumulate stats from 4736 documents (199761 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   75 batches submitted to accumulate stats from 4800 documents (202538 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   76 batches submitted to accumulate stats from 4864 documents (205021 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   77 batches submitted to accumulate stats from 4928 documents (207738 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   78 batches submitted to accumulate stats from 4992 documents (210494 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   79 batches submitted to accumulate stats from 5056 documents (213712 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   80 batches submitted to accumulate stats from 5120 documents (218193 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   81 batches submitted to accumulate stats from 5184 documents (220836 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   82 batches submitted to accumulate stats from 5248 documents (223738 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   83 batches submitted to accumulate stats from 5312 documents (228174 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   84 batches submitted to accumulate stats from 5376 documents (230479 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   85 batches submitted to accumulate stats from 5440 documents (233275 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   86 batches submitted to accumulate stats from 5504 documents (238015 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   87 batches submitted to accumulate stats from 5568 documents (239673 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   88 batches submitted to accumulate stats from 5632 documents (242658 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   89 batches submitted to accumulate stats from 5696 documents (245289 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   90 batches submitted to accumulate stats from 5760 documents (249275 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   91 batches submitted to accumulate stats from 5824 documents (252071 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   92 batches submitted to accumulate stats from 5888 documents (254451 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   93 batches submitted to accumulate stats from 5952 documents (257690 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   94 batches submitted to accumulate stats from 6016 documents (259638 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   95 batches submitted to accumulate stats from 6080 documents (261598 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   96 batches submitted to accumulate stats from 6144 documents (263291 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   97 batches submitted to accumulate stats from 6208 documents (267452 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   98 batches submitted to accumulate stats from 6272 documents (269945 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   99 batches submitted to accumulate stats from 6336 documents (272447 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   100 batches submitted to accumulate stats from 6400 documents (274888 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   101 batches submitted to accumulate stats from 6464 documents (280713 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   102 batches submitted to accumulate stats from 6528 documents (282572 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   103 batches submitted to accumulate stats from 6592 documents (284145 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   104 batches submitted to accumulate stats from 6656 documents (288611 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   105 batches submitted to accumulate stats from 6720 documents (291823 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   106 batches submitted to accumulate stats from 6784 documents (294392 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   107 batches submitted to accumulate stats from 6848 documents (296378 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   108 batches submitted to accumulate stats from 6912 documents (298682 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   109 batches submitted to accumulate stats from 6976 documents (301574 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   110 batches submitted to accumulate stats from 7040 documents (303124 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   111 batches submitted to accumulate stats from 7104 documents (304181 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   112 batches submitted to accumulate stats from 7168 documents (306146 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   113 batches submitted to accumulate stats from 7232 documents (308316 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   114 batches submitted to accumulate stats from 7296 documents (310460 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   115 batches submitted to accumulate stats from 7360 documents (312260 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   116 batches submitted to accumulate stats from 7424 documents (314358 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   117 batches submitted to accumulate stats from 7488 documents (316184 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   118 batches submitted to accumulate stats from 7552 documents (317752 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   119 batches submitted to accumulate stats from 7616 documents (319374 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   120 batches submitted to accumulate stats from 7680 documents (323408 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   121 batches submitted to accumulate stats from 7744 documents (325680 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   122 batches submitted to accumulate stats from 7808 documents (327134 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   123 batches submitted to accumulate stats from 7872 documents (328647 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   124 batches submitted to accumulate stats from 7936 documents (330187 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   125 batches submitted to accumulate stats from 8000 documents (332149 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   126 batches submitted to accumulate stats from 8064 documents (336793 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   127 batches submitted to accumulate stats from 8128 documents (339935 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   128 batches submitted to accumulate stats from 8192 documents (341705 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   129 batches submitted to accumulate stats from 8256 documents (344128 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   130 batches submitted to accumulate stats from 8320 documents (346653 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   131 batches submitted to accumulate stats from 8384 documents (348645 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   132 batches submitted to accumulate stats from 8448 documents (351050 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   133 batches submitted to accumulate stats from 8512 documents (353176 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   134 batches submitted to accumulate stats from 8576 documents (355176 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   135 batches submitted to accumulate stats from 8640 documents (358500 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   136 batches submitted to accumulate stats from 8704 documents (359838 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   137 batches submitted to accumulate stats from 8768 documents (364870 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   138 batches submitted to accumulate stats from 8832 documents (366187 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   139 batches submitted to accumulate stats from 8896 documents (368382 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   140 batches submitted to accumulate stats from 8960 documents (370703 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   141 batches submitted to accumulate stats from 9024 documents (374306 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   142 batches submitted to accumulate stats from 9088 documents (376664 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   143 batches submitted to accumulate stats from 9152 documents (379568 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   144 batches submitted to accumulate stats from 9216 documents (381393 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   145 batches submitted to accumulate stats from 9280 documents (383934 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   146 batches submitted to accumulate stats from 9344 documents (388704 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   147 batches submitted to accumulate stats from 9408 documents (390855 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   148 batches submitted to accumulate stats from 9472 documents (392797 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   149 batches submitted to accumulate stats from 9536 documents (396575 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   150 batches submitted to accumulate stats from 9600 documents (399552 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   151 batches submitted to accumulate stats from 9664 documents (401694 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   152 batches submitted to accumulate stats from 9728 documents (405133 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   153 batches submitted to accumulate stats from 9792 documents (409173 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   154 batches submitted to accumulate stats from 9856 documents (411291 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   155 batches submitted to accumulate stats from 9920 documents (413558 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   156 batches submitted to accumulate stats from 9984 documents (415951 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   157 batches submitted to accumulate stats from 10048 documents (422638 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   158 batches submitted to accumulate stats from 10112 documents (423819 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   159 batches submitted to accumulate stats from 10176 documents (427847 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   160 batches submitted to accumulate stats from 10240 documents (431649 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   161 batches submitted to accumulate stats from 10304 documents (434110 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   162 batches submitted to accumulate stats from 10368 documents (441209 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   163 batches submitted to accumulate stats from 10432 documents (443853 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   164 batches submitted to accumulate stats from 10496 documents (446249 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   165 batches submitted to accumulate stats from 10560 documents (447541 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   166 batches submitted to accumulate stats from 10624 documents (449131 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   167 batches submitted to accumulate stats from 10688 documents (452050 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   168 batches submitted to accumulate stats from 10752 documents (453962 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   169 batches submitted to accumulate stats from 10816 documents (458173 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   170 batches submitted to accumulate stats from 10880 documents (462113 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   171 batches submitted to accumulate stats from 10944 documents (464468 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   172 batches submitted to accumulate stats from 11008 documents (467017 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   173 batches submitted to accumulate stats from 11072 documents (469751 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   174 batches submitted to accumulate stats from 11136 documents (471527 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   175 batches submitted to accumulate stats from 11200 documents (474001 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   176 batches submitted to accumulate stats from 11264 documents (476032 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   177 batches submitted to accumulate stats from 11328 documents (478101 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   178 batches submitted to accumulate stats from 11392 documents (480289 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   179 batches submitted to accumulate stats from 11456 documents (483561 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   180 batches submitted to accumulate stats from 11520 documents (486219 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   181 batches submitted to accumulate stats from 11584 documents (489128 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   182 batches submitted to accumulate stats from 11648 documents (490788 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   183 batches submitted to accumulate stats from 11712 documents (493204 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   184 batches submitted to accumulate stats from 11776 documents (495383 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   185 batches submitted to accumulate stats from 11840 documents (497580 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   186 batches submitted to accumulate stats from 11904 documents (499907 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   187 batches submitted to accumulate stats from 11968 documents (502788 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   188 batches submitted to accumulate stats from 12032 documents (504547 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   189 batches submitted to accumulate stats from 12096 documents (506947 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   190 batches submitted to accumulate stats from 12160 documents (509240 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   191 batches submitted to accumulate stats from 12224 documents (511055 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   192 batches submitted to accumulate stats from 12288 documents (513360 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   193 batches submitted to accumulate stats from 12352 documents (514962 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   194 batches submitted to accumulate stats from 12416 documents (517000 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   195 batches submitted to accumulate stats from 12480 documents (518896 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   196 batches submitted to accumulate stats from 12544 documents (521122 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   197 batches submitted to accumulate stats from 12608 documents (528084 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   198 batches submitted to accumulate stats from 12672 documents (530003 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   199 batches submitted to accumulate stats from 12736 documents (532605 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   200 batches submitted to accumulate stats from 12800 documents (534653 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   201 batches submitted to accumulate stats from 12864 documents (536800 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   202 batches submitted to accumulate stats from 12928 documents (541116 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   203 batches submitted to accumulate stats from 12992 documents (543249 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   204 batches submitted to accumulate stats from 13056 documents (547407 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   205 batches submitted to accumulate stats from 13120 documents (548933 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   206 batches submitted to accumulate stats from 13184 documents (551026 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   207 batches submitted to accumulate stats from 13248 documents (552853 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   208 batches submitted to accumulate stats from 13312 documents (555481 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   209 batches submitted to accumulate stats from 13376 documents (557484 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   210 batches submitted to accumulate stats from 13440 documents (559075 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   211 batches submitted to accumulate stats from 13504 documents (564523 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   212 batches submitted to accumulate stats from 13568 documents (565965 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   213 batches submitted to accumulate stats from 13632 documents (567839 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   214 batches submitted to accumulate stats from 13696 documents (569640 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   215 batches submitted to accumulate stats from 13760 documents (571367 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   216 batches submitted to accumulate stats from 13824 documents (572801 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   217 batches submitted to accumulate stats from 13888 documents (577145 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   218 batches submitted to accumulate stats from 13952 documents (579218 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   219 batches submitted to accumulate stats from 14016 documents (583013 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   220 batches submitted to accumulate stats from 14080 documents (585262 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   221 batches submitted to accumulate stats from 14144 documents (587070 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   222 batches submitted to accumulate stats from 14208 documents (591711 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   223 batches submitted to accumulate stats from 14272 documents (593803 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   224 batches submitted to accumulate stats from 14336 documents (595638 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   225 batches submitted to accumulate stats from 14400 documents (597063 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   226 batches submitted to accumulate stats from 14464 documents (599036 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   227 batches submitted to accumulate stats from 14528 documents (600919 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   228 batches submitted to accumulate stats from 14592 documents (607683 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   229 batches submitted to accumulate stats from 14656 documents (609454 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   230 batches submitted to accumulate stats from 14720 documents (611205 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   231 batches submitted to accumulate stats from 14784 documents (612509 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   232 batches submitted to accumulate stats from 14848 documents (614164 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   233 batches submitted to accumulate stats from 14912 documents (615747 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   234 batches submitted to accumulate stats from 14976 documents (617548 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   235 batches submitted to accumulate stats from 15040 documents (621092 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   236 batches submitted to accumulate stats from 15104 documents (624804 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   237 batches submitted to accumulate stats from 15168 documents (628109 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   238 batches submitted to accumulate stats from 15232 documents (630260 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   239 batches submitted to accumulate stats from 15296 documents (632182 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   240 batches submitted to accumulate stats from 15360 documents (633664 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   241 batches submitted to accumulate stats from 15424 documents (635012 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   242 batches submitted to accumulate stats from 15488 documents (637840 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   243 batches submitted to accumulate stats from 15552 documents (639764 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   244 batches submitted to accumulate stats from 15616 documents (641163 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   245 batches submitted to accumulate stats from 15680 documents (646430 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   246 batches submitted to accumulate stats from 15744 documents (648720 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   247 batches submitted to accumulate stats from 15808 documents (650800 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   248 batches submitted to accumulate stats from 15872 documents (654413 virtual)
# 03/13/2023 21:12:34 - INFO - gensim.topic_coherence.text_analysis -   249 batches submitted to accumulate stats from 15936 documents (656519 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   250 batches submitted to accumulate stats from 16000 documents (658851 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   251 batches submitted to accumulate stats from 16064 documents (661602 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   252 batches submitted to accumulate stats from 16128 documents (663430 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   253 batches submitted to accumulate stats from 16192 documents (664845 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   254 batches submitted to accumulate stats from 16256 documents (668882 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   255 batches submitted to accumulate stats from 16320 documents (673314 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   256 batches submitted to accumulate stats from 16384 documents (678793 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   257 batches submitted to accumulate stats from 16448 documents (683575 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   258 batches submitted to accumulate stats from 16512 documents (684688 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   259 batches submitted to accumulate stats from 16576 documents (687475 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   260 batches submitted to accumulate stats from 16640 documents (689866 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   261 batches submitted to accumulate stats from 16704 documents (692018 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   262 batches submitted to accumulate stats from 16768 documents (693984 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   263 batches submitted to accumulate stats from 16832 documents (695090 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   264 batches submitted to accumulate stats from 16896 documents (696942 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   265 batches submitted to accumulate stats from 16960 documents (699468 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   266 batches submitted to accumulate stats from 17024 documents (702135 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   267 batches submitted to accumulate stats from 17088 documents (704072 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   268 batches submitted to accumulate stats from 17152 documents (705584 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   269 batches submitted to accumulate stats from 17216 documents (709149 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   270 batches submitted to accumulate stats from 17280 documents (711214 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   271 batches submitted to accumulate stats from 17344 documents (712950 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   272 batches submitted to accumulate stats from 17408 documents (716834 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   273 batches submitted to accumulate stats from 17472 documents (720334 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   274 batches submitted to accumulate stats from 17536 documents (724023 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   275 batches submitted to accumulate stats from 17600 documents (725452 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   276 batches submitted to accumulate stats from 17664 documents (726695 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   277 batches submitted to accumulate stats from 17728 documents (728889 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   278 batches submitted to accumulate stats from 17792 documents (731631 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   279 batches submitted to accumulate stats from 17856 documents (735685 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   280 batches submitted to accumulate stats from 17920 documents (736985 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   281 batches submitted to accumulate stats from 17984 documents (738927 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   282 batches submitted to accumulate stats from 18048 documents (740712 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   283 batches submitted to accumulate stats from 18112 documents (743891 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   284 batches submitted to accumulate stats from 18176 documents (745952 virtual)
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:12:35 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# ...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   195 batches submitted to accumulate stats from 12480 documents (518896 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   196 batches submitted to accumulate stats from 12544 documents (521122 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   197 batches submitted to accumulate stats from 12608 documents (528084 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   198 batches submitted to accumulate stats from 12672 documents (530003 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   199 batches submitted to accumulate stats from 12736 documents (532605 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   200 batches submitted to accumulate stats from 12800 documents (534653 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   201 batches submitted to accumulate stats from 12864 documents (536800 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   202 batches submitted to accumulate stats from 12928 documents (541116 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   203 batches submitted to accumulate stats from 12992 documents (543249 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   204 batches submitted to accumulate stats from 13056 documents (547407 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   205 batches submitted to accumulate stats from 13120 documents (548933 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   206 batches submitted to accumulate stats from 13184 documents (551026 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   207 batches submitted to accumulate stats from 13248 documents (552853 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   208 batches submitted to accumulate stats from 13312 documents (555481 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   209 batches submitted to accumulate stats from 13376 documents (557484 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   210 batches submitted to accumulate stats from 13440 documents (559075 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   211 batches submitted to accumulate stats from 13504 documents (564523 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   212 batches submitted to accumulate stats from 13568 documents (565965 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   213 batches submitted to accumulate stats from 13632 documents (567839 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   214 batches submitted to accumulate stats from 13696 documents (569640 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   215 batches submitted to accumulate stats from 13760 documents (571367 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   216 batches submitted to accumulate stats from 13824 documents (572801 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   217 batches submitted to accumulate stats from 13888 documents (577145 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   218 batches submitted to accumulate stats from 13952 documents (579218 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   219 batches submitted to accumulate stats from 14016 documents (583013 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   220 batches submitted to accumulate stats from 14080 documents (585262 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   221 batches submitted to accumulate stats from 14144 documents (587070 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   222 batches submitted to accumulate stats from 14208 documents (591711 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   223 batches submitted to accumulate stats from 14272 documents (593803 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   224 batches submitted to accumulate stats from 14336 documents (595638 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   225 batches submitted to accumulate stats from 14400 documents (597063 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   226 batches submitted to accumulate stats from 14464 documents (599036 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   227 batches submitted to accumulate stats from 14528 documents (600919 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   228 batches submitted to accumulate stats from 14592 documents (607683 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   229 batches submitted to accumulate stats from 14656 documents (609454 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   230 batches submitted to accumulate stats from 14720 documents (611205 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   231 batches submitted to accumulate stats from 14784 documents (612509 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   232 batches submitted to accumulate stats from 14848 documents (614164 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   233 batches submitted to accumulate stats from 14912 documents (615747 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   234 batches submitted to accumulate stats from 14976 documents (617548 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   235 batches submitted to accumulate stats from 15040 documents (621092 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   236 batches submitted to accumulate stats from 15104 documents (624804 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   237 batches submitted to accumulate stats from 15168 documents (628109 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   238 batches submitted to accumulate stats from 15232 documents (630260 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   239 batches submitted to accumulate stats from 15296 documents (632182 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   240 batches submitted to accumulate stats from 15360 documents (633664 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   241 batches submitted to accumulate stats from 15424 documents (635012 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   242 batches submitted to accumulate stats from 15488 documents (637840 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   243 batches submitted to accumulate stats from 15552 documents (639764 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   244 batches submitted to accumulate stats from 15616 documents (641163 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   245 batches submitted to accumulate stats from 15680 documents (646430 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   246 batches submitted to accumulate stats from 15744 documents (648720 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   247 batches submitted to accumulate stats from 15808 documents (650800 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   248 batches submitted to accumulate stats from 15872 documents (654413 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   249 batches submitted to accumulate stats from 15936 documents (656519 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   250 batches submitted to accumulate stats from 16000 documents (658851 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   251 batches submitted to accumulate stats from 16064 documents (661602 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   252 batches submitted to accumulate stats from 16128 documents (663430 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   253 batches submitted to accumulate stats from 16192 documents (664845 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   254 batches submitted to accumulate stats from 16256 documents (668882 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   255 batches submitted to accumulate stats from 16320 documents (673314 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   256 batches submitted to accumulate stats from 16384 documents (678793 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   257 batches submitted to accumulate stats from 16448 documents (683575 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   258 batches submitted to accumulate stats from 16512 documents (684688 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   259 batches submitted to accumulate stats from 16576 documents (687475 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   260 batches submitted to accumulate stats from 16640 documents (689866 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   261 batches submitted to accumulate stats from 16704 documents (692018 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   262 batches submitted to accumulate stats from 16768 documents (693984 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   263 batches submitted to accumulate stats from 16832 documents (695090 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   264 batches submitted to accumulate stats from 16896 documents (696942 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   265 batches submitted to accumulate stats from 16960 documents (699468 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   266 batches submitted to accumulate stats from 17024 documents (702135 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   267 batches submitted to accumulate stats from 17088 documents (704072 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   268 batches submitted to accumulate stats from 17152 documents (705584 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   269 batches submitted to accumulate stats from 17216 documents (709149 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   270 batches submitted to accumulate stats from 17280 documents (711214 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   271 batches submitted to accumulate stats from 17344 documents (712950 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   272 batches submitted to accumulate stats from 17408 documents (716834 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   273 batches submitted to accumulate stats from 17472 documents (720334 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   274 batches submitted to accumulate stats from 17536 documents (724023 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   275 batches submitted to accumulate stats from 17600 documents (725452 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   276 batches submitted to accumulate stats from 17664 documents (726695 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   277 batches submitted to accumulate stats from 17728 documents (728889 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   278 batches submitted to accumulate stats from 17792 documents (731631 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   279 batches submitted to accumulate stats from 17856 documents (735685 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   280 batches submitted to accumulate stats from 17920 documents (736985 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   281 batches submitted to accumulate stats from 17984 documents (738927 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   282 batches submitted to accumulate stats from 18048 documents (740712 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   283 batches submitted to accumulate stats from 18112 documents (743891 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   284 batches submitted to accumulate stats from 18176 documents (745952 virtual)
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   serializing accumulator to return to master...
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   accumulator serialized
# 03/13/2023 21:21:44 - INFO - gensim.topic_coherence.text_analysis -   7 accumulators retrieved from output queue
# 03/13/2023 21:21:45 - INFO - gensim.topic_coherence.text_analysis -   accumulated word occurrence stats for 761263 virtual documents
# 03/13/2023 21:21:45 - INFO - gensim.models.keyedvectors -   loading projection weights from /home/felipe/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz
# 03/13/2023 21:22:14 - INFO - gensim.utils -   KeyedVectors lifecycle event {'msg': 'loaded (3000000, 300) matrix of type float32 from /home/felipe/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz', 'binary': True, 'encoding': 'utf8', 'datetime': '2023-03-13T21:22:14.448247', 'gensim': '4.2.0', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-84-generic-x86_64-with-glibc2.29', 'event': 'load_word2vec_format'}
# {'npmi_score': 0.15184204075800584, 'we_score': 0.2233993, 'irbo_score': 0.9883366881035277, 'td_score': 0.74}
# Duration: 0:12:27.638308

# %%
#How to read the results

''' 

with open(key_name, 'rb') as f:
    results_file = pickle.load(f)

import pandas as pd
pd.DataFrame(results_file)
pd.DataFrame(results_file).mean()

'''
